# %% [markdown]
# <a href="https://colab.research.google.com/github/hamadnmirza/Earnings-Summary/blob/main/OpenAI_Earnings_Call_Summation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 3.3 MB/s eta 0:00:00

# %%
import openai

# %% [markdown]
# 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

# %%
from getpass import getpass
openai.api_key = getpass()
# Out:
# ··········

# %%
prompt = "I am a highly intelligent question answering bot. If you ask me a question that is rooted in truth, I will give you the answer. If you ask me a question that is nonsense, trickery, or has no clear answer, I will respond with \"Unknown\". Q: Who is the greatest investor of all time?\n\n"
engine = 'text-davinci-003'
response = openai.Completion.create(
  engine=engine, 
  prompt=prompt,
  temperature=0.3, # The temperature controls the randomness of the response, represented as a range from 0 to 1. A lower value of temperature means the API will respond with the first thing that the model sees; a higher value means the model evaluates possible responses that could fit into the context before spitting out the result.
  max_tokens=140,
  top_p=1, # Top P controls how many random results the model should consider for completion, as suggested by the temperature dial, thus determining the scope of randomness. Top P’s range is from 0 to 1. A lower value limits creativity, while a higher value expands its horizons.
  frequency_penalty=0,
  presence_penalty=1
)

response
# Out:
# <OpenAIObject text_completion id=cmpl-6vj6kLchV6zo5HYmcgVaKUzzzy2jN at 0x7f000db8e0e0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nThe greatest investor of all time is widely considered to be Warren Buffett."
#     }
#   ],
#   "created": 1679216110,
#   "id": "cmpl-6vj6kLchV6zo5HYmcgVaKUzzzy2jN",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 15,
#     "prompt_tokens": 66,
#     "total_tokens": 81
#   }
# }

# %%
import requests

url = "https://raw.githubusercontent.com/hamadnmirza/Earnings-Summary/main/Black%20Rose%20earnings%20summary"
response = requests.get(url)
transcript = response.text

transcript
# Out:
# 'Corporate Participants:\nAnup Jatia — Executive Director\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nAnalysts:\nUnidentified Participant — — Analyst\n\nManish Yadav — — Analyst\n\nPresentation:\nOperator\n\nGood morning, ladies and gentlemen, and thank you for attending this virtual meeting. It’s a pleasure to welcome you on behalf of Black Rose Industries Limited and SKP Securities to this Q3 FY22 Financial Results Webinar. We have with us Mr. Anup Jatia, Executive Director along with Mr. Ambarish Daga, Joint CFO and Investor Relations officer.\n\nKindly note that during this discussion, there may be certain forward-looking statements. And these must be viewed in conjunction with the risks that the Company faces. All participant lines have been kept on mute, and the webinar is being recorded for compliance reasons.\n\nWe’ll have the opening remarks from Mr. Anup Jatia followed by a presentation, and we’ll have the Q&A session thereafter. Thank you, and over to you Anup-ji.\n\nAnup Jatia — Executive Director\n\nThank you, Naveen-ji, and good morning to all. We are now in a world which, as you see in the news regularly, that artificial intelligence is starting to become — play a major role in people’s lives. Today’s presentation will be done by Ambarish and myself using our normal intelligence. Maybe in the future one day we will have some artificial intelligence chatbot doing these webinars. But so far, you have to bear with us. Thank you very much and I’ll hand over to Ambarish.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nThank you, Anup-ji. A very warm welcome to everyone. And I’ll just start giving the presentation. Please confirm that the screen is visible to everyone.\n\nOperator\n\nYes, Ambarish, please go ahead.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nJust give me a moment while the [Indecipherable]. Okay, so we start with a small disclaimer regarding the forward-looking statements. They carry the risks that the Company faces.\n\nMoving on to the first slide, so as many of you are already aware, Black Rose is primarily into two business segments, one is the Chemical Distribution and the other is Chemical Manufacturing. The Chemical Distribution business is where we import and distribute specialty and performance chemicals from the leading chemical manufacturing companies across the Group. We have direct working relationships with many of the main chemical producers based out of Japan, Germany and Thailand.\n\nThe Chemical Manufacturing division was started with the setup of Asia’s first acrylamide liquid plant in 2013. The current installed capacity for the Acrylamide liquid is 32,000 metric tons, out of which 20,000 tons is earmarked for merchant sales and the balance is for our captive consumption.\n\nThe next order that the Company started in the same facility was the polyacrylamide liquid which has a current installed capacity of 40,000 metric tons. And currently, our focus in this segment is mainly to cater to the ceramic binder industry at Morbi.\n\nLast year, we started with two new products in the same chemistry. The first was and methanol N-Methylol Acrylamide which we started with a capacity of 2,000 metric tons in February last year. And we are now receiving acceptance and orders from various [Indecipherable] companies who use these materials.\n\nIn June last year, we also started producing Acrylamide solid, becoming the only company outside of China to do so. We have an installed capacity of 3,600 metric tons per annum. And this product is sold both locally as well as internationally. Having taken the REACH registration, we expect good volumes from this business segment.\n\nBR Chemicals Company Limited is our 100% subsidiary based in Japan and is engaged locally in the distribution as well as exports of chemicals. The other legacy businesses contribute overall less than 1% of our business.\n\nNow moving on to the performance of the quarter gone by ...

# %%
prompt = f"{transcript}\n\ntl;dr:"

prompt
# Out:
# 'Corporate Participants:\nAnup Jatia — Executive Director\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nAnalysts:\nUnidentified Participant — — Analyst\n\nManish Yadav — — Analyst\n\nPresentation:\nOperator\n\nGood morning, ladies and gentlemen, and thank you for attending this virtual meeting. It’s a pleasure to welcome you on behalf of Black Rose Industries Limited and SKP Securities to this Q3 FY22 Financial Results Webinar. We have with us Mr. Anup Jatia, Executive Director along with Mr. Ambarish Daga, Joint CFO and Investor Relations officer.\n\nKindly note that during this discussion, there may be certain forward-looking statements. And these must be viewed in conjunction with the risks that the Company faces. All participant lines have been kept on mute, and the webinar is being recorded for compliance reasons.\n\nWe’ll have the opening remarks from Mr. Anup Jatia followed by a presentation, and we’ll have the Q&A session thereafter. Thank you, and over to you Anup-ji.\n\nAnup Jatia — Executive Director\n\nThank you, Naveen-ji, and good morning to all. We are now in a world which, as you see in the news regularly, that artificial intelligence is starting to become — play a major role in people’s lives. Today’s presentation will be done by Ambarish and myself using our normal intelligence. Maybe in the future one day we will have some artificial intelligence chatbot doing these webinars. But so far, you have to bear with us. Thank you very much and I’ll hand over to Ambarish.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nThank you, Anup-ji. A very warm welcome to everyone. And I’ll just start giving the presentation. Please confirm that the screen is visible to everyone.\n\nOperator\n\nYes, Ambarish, please go ahead.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nJust give me a moment while the [Indecipherable]. Okay, so we start with a small disclaimer regarding the forward-looking statements. They carry the risks that the Company faces.\n\nMoving on to the first slide, so as many of you are already aware, Black Rose is primarily into two business segments, one is the Chemical Distribution and the other is Chemical Manufacturing. The Chemical Distribution business is where we import and distribute specialty and performance chemicals from the leading chemical manufacturing companies across the Group. We have direct working relationships with many of the main chemical producers based out of Japan, Germany and Thailand.\n\nThe Chemical Manufacturing division was started with the setup of Asia’s first acrylamide liquid plant in 2013. The current installed capacity for the Acrylamide liquid is 32,000 metric tons, out of which 20,000 tons is earmarked for merchant sales and the balance is for our captive consumption.\n\nThe next order that the Company started in the same facility was the polyacrylamide liquid which has a current installed capacity of 40,000 metric tons. And currently, our focus in this segment is mainly to cater to the ceramic binder industry at Morbi.\n\nLast year, we started with two new products in the same chemistry. The first was and methanol N-Methylol Acrylamide which we started with a capacity of 2,000 metric tons in February last year. And we are now receiving acceptance and orders from various [Indecipherable] companies who use these materials.\n\nIn June last year, we also started producing Acrylamide solid, becoming the only company outside of China to do so. We have an installed capacity of 3,600 metric tons per annum. And this product is sold both locally as well as internationally. Having taken the REACH registration, we expect good volumes from this business segment.\n\nBR Chemicals Company Limited is our 100% subsidiary based in Japan and is engaged locally in the distribution as well as exports of chemicals. The other legacy businesses contribute overall less than 1% of our business.\n\nNow moving on to the performance of the quarter gone by ...

# %%
words = transcript.split(" ")

# show the first 20 words
words[:20]
# Out:
# ['Corporate',
#  'Participants:\nAnup',
#  'Jatia',
#  '—',
#  'Executive',
#  'Director\n\nAmbarish',
#  'Daga',
#  '—',
#  'Joint',
#  'CFO',
#  'and',
#  'Investor',
#  'Relations',
#  'Officer\n\nAnalysts:\nUnidentified',
#  'Participant',
#  '—',
#  '—',
#  'Analyst\n\nManish',
#  'Yadav',
#  '—']

# %%
import numpy as np
chunks = np.array_split(words, 6)
chunks
# Out:
# [array(['Corporate', 'Participants:\nAnup', 'Jatia', ..., 'sales', 'for',
#         'the'], dtype='<U37'),
#  array(['Company', 'during', 'the', ..., 'improving', 'the', 'product,'],
#        dtype='<U37'),
#  array(['so', 'that', 'we', ..., 'now', 'is', 'not'], dtype='<U37'),
#  array(['for', 'the', 'Performance', ..., 'be', 'made', 'on'], dtype='<U37'),
#  array(['any', 'of', 'our', ..., 'sir.', 'That’s', 'all'], dtype='<U37'),
#  array(['from', 'my', 'side.', ..., 'Executive', 'Director\n\nThank',
#         'you.\n'], dtype='<U37')]

# %%
sentences = ' '.join(list(chunks[0]))
sentences
# Out:
# 'Corporate Participants:\nAnup Jatia — Executive Director\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nAnalysts:\nUnidentified Participant — — Analyst\n\nManish Yadav — — Analyst\n\nPresentation:\nOperator\n\nGood morning, ladies and gentlemen, and thank you for attending this virtual meeting. It’s a pleasure to welcome you on behalf of Black Rose Industries Limited and SKP Securities to this Q3 FY22 Financial Results Webinar. We have with us Mr. Anup Jatia, Executive Director along with Mr. Ambarish Daga, Joint CFO and Investor Relations officer.\n\nKindly note that during this discussion, there may be certain forward-looking statements. And these must be viewed in conjunction with the risks that the Company faces. All participant lines have been kept on mute, and the webinar is being recorded for compliance reasons.\n\nWe’ll have the opening remarks from Mr. Anup Jatia followed by a presentation, and we’ll have the Q&A session thereafter. Thank you, and over to you Anup-ji.\n\nAnup Jatia — Executive Director\n\nThank you, Naveen-ji, and good morning to all. We are now in a world which, as you see in the news regularly, that artificial intelligence is starting to become — play a major role in people’s lives. Today’s presentation will be done by Ambarish and myself using our normal intelligence. Maybe in the future one day we will have some artificial intelligence chatbot doing these webinars. But so far, you have to bear with us. Thank you very much and I’ll hand over to Ambarish.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nThank you, Anup-ji. A very warm welcome to everyone. And I’ll just start giving the presentation. Please confirm that the screen is visible to everyone.\n\nOperator\n\nYes, Ambarish, please go ahead.\n\nAmbarish Daga — Joint CFO and Investor Relations Officer\n\nJust give me a moment while the [Indecipherable]. Okay, so we start with a small disclaimer regarding the forward-looking statements. They carry the risks that the Company faces.\n\nMoving on to the first slide, so as many of you are already aware, Black Rose is primarily into two business segments, one is the Chemical Distribution and the other is Chemical Manufacturing. The Chemical Distribution business is where we import and distribute specialty and performance chemicals from the leading chemical manufacturing companies across the Group. We have direct working relationships with many of the main chemical producers based out of Japan, Germany and Thailand.\n\nThe Chemical Manufacturing division was started with the setup of Asia’s first acrylamide liquid plant in 2013. The current installed capacity for the Acrylamide liquid is 32,000 metric tons, out of which 20,000 tons is earmarked for merchant sales and the balance is for our captive consumption.\n\nThe next order that the Company started in the same facility was the polyacrylamide liquid which has a current installed capacity of 40,000 metric tons. And currently, our focus in this segment is mainly to cater to the ceramic binder industry at Morbi.\n\nLast year, we started with two new products in the same chemistry. The first was and methanol N-Methylol Acrylamide which we started with a capacity of 2,000 metric tons in February last year. And we are now receiving acceptance and orders from various [Indecipherable] companies who use these materials.\n\nIn June last year, we also started producing Acrylamide solid, becoming the only company outside of China to do so. We have an installed capacity of 3,600 metric tons per annum. And this product is sold both locally as well as internationally. Having taken the REACH registration, we expect good volumes from this business segment.\n\nBR Chemicals Company Limited is our 100% subsidiary based in Japan and is engaged locally in the distribution as well as exports of chemicals. The other legacy businesses contribute overall less than 1% of our business.\n\nNow moving on to the performance of the quarter gone by ...

# %%
prompt = f"{sentences}\n\ntl;dr:"

response = openai.Completion.create(
    engine="text-davinci-003", 
    prompt=prompt,
    temperature=0.3, # The temperature controls the randomness of the response, represented as a range from 0 to 1. A lower value of temperature means the API will respond with the first thing that the model sees; a higher value means the model evaluates possible responses that could fit into the context before spitting out the result.
    max_tokens=140,
    top_p=1, # Top P controls how many random results the model should consider for completion, as suggested by the temperature dial, thus determining the scope of randomness. Top P’s range is from 0 to 1. A lower value limits creativity, while a higher value expands its horizons.
    frequency_penalty=0,
    presence_penalty=1
)

response_text = response["choices"][0]["text"]
response_text
# Out:
# '\nAt this virtual meeting, Anup Jatia and Ambarish Daga presented the Q3 FY22 Financial Results for Black Rose Industries Limited. They discussed the two business segments of the company, Chemical Distribution and Chemical Manufacturing. They also discussed the performance of the quarter, the balance sheet snapshot, the segment-wise distribution of revenue and EBITDA, as well as the revenue and geographical mix.'

# %%
summary_responses = []

for chunk in chunks:
    
    sentences = ' '.join(list(chunk))

    prompt = f"{sentences}\n\ntl;dr:"

    response = openai.Completion.create(
        engine="text-davinci-003", 
        prompt=prompt,
        temperature=0.3, # The temperature controls the randomness of the response, represented as a range from 0 to 1. A lower value of temperature means the API will respond with the first thing that the model sees; a higher value means the model evaluates possible responses that could fit into the context before spitting out the result.
        max_tokens=150,
        top_p=1, # Top P controls how many random results the model should consider for completion, as suggested by the temperature dial, thus determining the scope of randomness. Top P’s range is from 0 to 1. A lower value limits creativity, while a higher value expands its horizons.
        frequency_penalty=0,
        presence_penalty=1
    )

    response_text = response["choices"][0]["text"]
    summary_responses.append(response_text)

full_summary = "".join(summary_responses)

print("full summary")
print(full_summary)
# Out:
# full summary
#
# Black Rose Industries Limited held a virtual meeting to discuss their Q3 FY22 Financial Results. Anup Jatia, Executive Director, and Ambarish Daga, Joint CFO and Investor Relations Officer, presented the results. The Company primarily operates in two business segments: Chemical Distribution and Chemical Manufacturing. The presentation included a snapshot of the profit and loss statement, balance sheet highlights, segment-wise distribution of revenue and EBITDA, and revenue and geographical mix.
#
# The Distribution segment saw a 54% increase in total revenue during Q3, driven by high demand in the US oil and gas sector and lower freight costs. The Manufacturing segment's revenue remained largely stable due to lower price realization. Export volumes for acrylamide liquid decreased due to reduced demand from overseas customers. For the current quarter, the Company expects continued growth in exports, higher sales of resorcinol, and improved performance in the Performance Chemicals business.
# NMA has received approvals from domestic and international customers, and we expect sales to increase in the coming quarters. We are also doing R&D on polyacrylamide solid and polycarboxylic acid, and have completed one version of our product for testing. We are also looking into setting up a specialty chemical production facility at our existing location in Jhagadia. The total capex incurred so far is INR58 crores, with an additional INR1.5 crores spent this quarter. We are also discussing the feasibility of setting up a Performance Chemical production facility.
#
# The Performance Chemicals side of the company is in discussions with a partner to set up a manufacturing facility at its site. The company is also looking into expanding its export portfolio and taking EU REACH registration in order to overcome the current slowdowns in the market. The company has experienced pain from falling prices, but these have now subsided and the prices are stable.
#
# Anup Jatia, Executive Director of UPL Limited, discussed the company's sales performance and pricing of BRILBIND. He noted that the company has seen a reduction in costs due to lower prices of acrylamide and acrylic acid, which are two major raw materials used to make BRILBIND. He also stated that the contribution of BRILBIND to total sales is not significant. Lastly, he mentioned that the company is aiming to keep its average collection period within 60 days.
#
# Anup Jatia, the Executive Director of SKP Securities, thanked investors for their support and discussed the company's plans for the future. He said that there are no plans to de-merge the distribution and manufacturing divisions at this time, and that the company is working closely with its Japanese principals to expand activities in India. He also said that the company is looking to partner with companies to develop new technologies related to green chemistries and bio-renewable raw materials. Finally, he said that the EBITDA margins for the Manufacturing division can vary between 10% and 30%, depending on market conditions.
